# %%
import gdown

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\ASUS\\End-to-end-waste-detection-model-using-YOLO-v5'

# %%
url = "https://drive.google.com/file/d/1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "data/waste_data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61
# From (redirected): https://drive.google.com/uc?/export=download&id=1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61&confirm=t&uuid=ae1e8975-a3ac-4f89-8411-fe0f3a0f6333
# To: c:\Users\ASUS\End-to-end-waste-detection-model-using-YOLO-v5\data\waste_data.zip
# 100%|██████████| 40.1M/40.1M [00:13<00:00, 3.05MB/s]
# 'data/waste_data.zip'

# %%
# %pwd
# Out:
# 'c:\\Users\\ASUS\\End-to-end-waste-detection-model-using-YOLO-v5'
